# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhanavijayan/ML_OPS_Tasks/blob/main/LR_Supermarket.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

df = pd.read_csv('supermarket_sample.csv')

X = df[['Foot_Traffic']]
y = df['Shrinkage_INR']

model = LinearRegression()
model.fit(X, y)

print("Slope (m):", model.coef_[0])
print("Intercept (b):", model.intercept_)

prediction = model.predict([[300]])
print("Predicted shrinkage: ₹", round(prediction[0], 2))

print("R² score:", model.score(X, y))
# Out:
# Slope (m): 1.7799561356276918
# Intercept (b): 20.295082441352292
# Predicted shrinkage: ₹ 554.28
# R² score: 0.7209063544793947
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
